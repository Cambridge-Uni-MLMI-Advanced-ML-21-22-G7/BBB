# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from typing import Union, Tuple
import numpy as np
import torch
from typing import Union, Tuple
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.dataset import T_co
from torchvision import datasets, transforms
import pandas as pd
import matplotlib.pyplot as plt

from bbb.config.constants import MUSHROOM_DATASET_PATH
from bbb.data import generate_modified_regression_data
from bbb.utils.pytorch_setup import DEVICE

# %%
train_data = generate_modified_regression_data(train=True, size=1000, batch_size=1000, shuffle=True)
test_data = generate_modified_regression_data(train=False, size=1000, batch_size=1000, shuffle=True)

fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.scatter(test_data.dataset[:][0], test_data.dataset[:][1], marker='x')
ax.scatter(train_data.dataset[:][0], train_data.dataset[:][1], marker='x')
